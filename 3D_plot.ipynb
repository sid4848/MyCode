# %%
g = Graphics()

# %%
type(g)
# Out:
# <class 'sage.plot.graphics.Graphics'>

# %% [raw]
# g.show()

# %%
g += circle( (0,0), 0.5, color='green')

# %%
g.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g = Graphics()
g += plot(sin(x), x, 0, 2*pi, color='blue', frame=True, axes_labels=['$x$', '$sin(x)$'], fill=True)
g += plot(cos(x), x, 0, 2*pi, color='yellow', fill=True)
g += circle( (pi,0), 0.25, color='green')
g += line([(pi,0), (pi+0.5,0.5)], color='red')
g += text("watch this cross over", (pi+0.5, 0.5))
g.show()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
p = plot(sin(x), x, 0, 2*pi, color='blue')
p.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def pltsin(a,b):
    p1 = plot(sin(a*x), x, 0, 5*pi, color='blue')
    p2 = plot(cos(b*x), x, 0, 5*pi, color='green')
    (p1+p2).show() 
from sage.repl.ipython_kernel.interact import sage_interactive
sage_interactive(pltsin, a=(0.5, 3), b=(0.5, 3))

# %%
var('y')
# Out:
# y

# %%
plot3d(sin(x)*cos(y), (x,-10,10), (y,-10,10))
# Out:
# Graphics3d Object

# %%
def pltsurf(a,b):
    p = plot3d(sin(x)*cos(y), (x,-10,10), (y,-10,10))
    p.show()
from sage.repl.ipython_kernel.interact import sage_interactive
sage_interactive(pltsurf, a=(0.5, 3), b=(0.5, 3))

# %%
contour_ plot?

# %%
contour_ plot

# %%
contour_plot(sin(x)*cos(y), (x,-10,10), (y,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(sin(x)*cos(y), (x,-10,10), (y,-10,10), cmap='hsv', colorbar=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(exp(-(x*x+y*y)), (x,-10,10), (y,-10,10), cmap='hsv', colorbar=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(exp(-(x*x+y*y)), (x,-3,3), (y,-3,3))
# Out:
# Graphics3d Object

# %%
contour_plot(exp(-(x*x+y*y)), (x,-3,3), (y,-3,3), cmap='hsv', colorbar=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(exp(-(x*x+y*y)), (x,-3,3), (y,-3,3), cmap='hot', colorbar=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(exp(-(x*x+y*y)), (x,-3,3), (y,-3,3), cmap='bone', colorbar=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(exp(-(x*x+y*y)), (x,-3,3), (y,-3,3), cmap='hot', colorbar=True, fill=false)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(exp(-4*(x*x+y*y)) + exp(-2*((x-1)*(x-1)+(y-1)*(y-1))), (x,-3,3), (y,-3,3), cmap='hot', colorbar=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(exp(-4*(x*x+y*y)) + exp(-2*((x-1)*(x-1)+(y-1)*(y-1))), (x,-3,3), (y,-3,3), cmap='hot', colorbar=True, fill=false)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
contour_plot(exp(-4*(x*x+y*y)) + exp(-2*((x-1)*(x-1)+(y-1)*(y-1))), (x,-3,3), (y,-3,3), cmap='bone', colorbar=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(exp(-4*(x*x+y*y)) + exp(-2*((x-1)*(x-1)+(y-1)*(y-1))), (x,-3,3), (y,-3,3))
# Out:
# Graphics3d Object

# %%
plot3d(exp(-(x^2+y^2)*sin(x^2+y^2)), (x,-100,100), (y,-100,100))
# Out:
# Graphics3d Object

# %%
contour_plot(exp(-(x^2+y^2)*sin(x^2+y^2)), (x,-200,200), (y,-200,200), cmap='bone')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('a')
# Out:
# a

# %%
f = a^2 - 3*a

# %%
revolution_plot3d(f, (a,0,2), show_curve=True, opacity=0.7)
# Out:
# Graphics3d Object

# %%
g = Graphics()
g += sphere( (0,0,0), size=1, color='green', opacity=0.6)
g += cube( (1,0,0), size=1, color='red', opacity=0.6)
g += dodecahedron( (2,0,0), size=1, color='blue', opacity=0.6)
g.show()
# Out:
# Graphics3d Object

# %%
t = Tachyon(xres=512, yres=512, camera_center=(4,0.3,0))
t.light((4,3,2), 0.2, (1,1,1))
t.texture('t0', ambient=0.1, diffuse=0.9, specular=0.5, opacity=1.0, color=(1.0,0,1.0))
t.texture('t1', ambient=0.1, diffuse=0.9, specular=0.3, opacity=1.0, color=(0,1.0,0))
t.texture('t2', ambient=0.2, diffuse=0.7, specular=0.5, opacity=0.7, color=(0,0,1.0))
t.texture('t13', ambient=0.1, diffuse=0.8, specular=0.3, opacity=0.8, color=(0,1.0,1.0))
k= 0
for i in srange(-1,1.0,0.05):
    k +=1
    t.sphere((i,i^2-0.5, i^3), 0.1, 't%s'%(k%4))
t.show()

# %%
contour_plot?

# %%
import matplotlib.cm
matplotlib.cm.datad.keys()
# Out:
# dict_keys(['Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectr
# ...
