# %%
c1 = complex_root_of(x^6 - 5*x + 1, 0 )
c1.n()
# Out:
# 0.200012804917876

# %%
c2 = complex_root_of(x^6 - 5*x + 1, 1 )
c2.n()
# Out:
# 1.33568729605726

# %%
c3 = complex_root_of(x^6 - 5*x + 1, 2 )
c3.n()
# Out:
# -1.15357040048240 - 0.812646548862506*I

# %%
c4 = complex_root_of(x^6 - 5*x + 1, 3 )
c4.n()
# Out:
# -1.15357040048240 + 0.812646548862506*I

# %%
c5 = complex_root_of(x^6 - 5*x + 1, 4 )
c5.n()
# Out:
# 0.385720349994829 - 1.31572918238559*I

# %%
c6 = complex_root_of(x^6 - 5*x + 1, 5 )
c6.n()
# Out:
# 0.385720349994829 + 1.31572918238559*I

# %%
f(x) = x^6 - 5*x + 1
C = complex_plot(f, (-3, 3), (-3, 3))
C
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
c = circle((0,0), 2)
(c + C).show()
# Out:
# Graphics object consisting of 2 graphics primitives
